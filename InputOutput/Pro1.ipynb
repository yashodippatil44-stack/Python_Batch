# %% [markdown]
# ## Program 1: Integer input

# %%
num = int(input("Enter an integer: "))

print("You entered integer:", num)

# %% [markdown]
# ## Program 2: String input

# %%
name = input("Enter a string: ")

print("You entered string:", name)

# %% [markdown]
# ## Program 3: Float input

# %%
num = float(input("Enter a float number: "))

print("You entered float:", num)

# %% [markdown]
# ## Program 4: Sum of two integers

# %%
num1 = int(input("Enter first integer: "))
num2 = int(input("Enter second integer: "))

sum = num1 + num2

print("Sum of", num1, "and", num2, "is", sum)

# %% [markdown]
# ## Program 5: Name and age

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print("name:", name)
print("age:", age)

# %% [markdown]
# ## Program 6: Average of three floats

# %%
num1 = float(input("Enter first float number: "))
num2 = float(input("Enter second float number: "))
num3 = float(input("Enter third float number: "))

average = (num1 + num2 + num3) / 3

print("Average of numbers is", round(average, 2))

# %% [markdown]
# ## Program 7: Type of integer

# %%
num = int(input("Enter an integer: "))

print("The type of entered value is", type(num))

# %% [markdown]
# ## Program 8: Type of string

# %%
text = input("Enter a string: ")

print("The type of entered value is", type(text))

# %% [markdown]
# ## Program 9: Type of float

# %%
num = float(input("Enter a float number: "))

print("The type of entered value is", type(num))

# %% [markdown]
# ## Program 10: Multiplication of two integers

# %%
num1 = int(input("Enter first integer: "))
num2 = int(input("Enter second integer: "))

multiplication = num1 * num2

print("Multiplication of", num1, "and", num2, "is", multiplication)
